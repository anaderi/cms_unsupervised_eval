# %% [markdown]
# # Tests of linear tranformations
#
# ## In this notebook I debug different algortihms of metric learning based on finding good linear tranformations

# %%
import utils
import linear_transform

# %% [markdown]
# # Tests with sandwich data

# %%
data, labels = linear_transform.sandwich_data(num_classes=6, num_points=20, dist=.2)
linear_transform.plot_data(data, labels)

# %%
inv_potential = linear_transform.power_potential(power=-1)

# Now let's apply some transformation technique
transforms = linear_transform.generate_linear_transform(data, labels, n_neighbors=30, iterations=1000, eps=0.1,
    max_class_data_on_iteration=50, balance_forces=True, potential=inv_potential)

for stage, transform in enumerate(transforms):
    confusion_matrix = utils.distance_quality_matrix(data, labels, n_neighbors=20)
    if stage % 100 == 0:
        print transform
        X_new = numpy.dot(data, transform)
        linear_transform.plot_data(X_new, labels)
        qm = utils.distance_quality_matrix(X_new, labels, n_neighbors=20)
        utils.plot_confusion_matrix(qm)
        show()
# Out:
# [[  9.41574187e-01   1.34278018e-04]
#  [  1.34278018e-04   1.06205122e+00]]
# [[  1.85196527e-02  -6.25384518e-01]
#  [ -5.98167122e+00   2.55989929e+02]]
# [[  1.71686843e+00  -7.34253789e+01]
#  [ -7.02653097e+02   3.00509748e+04]]
# [[  2.01540754e+02  -8.61946795e+03]
#  [ -8.24850501e+04   3.52770956e+06]]
# [[  2.36590410e+04  -1.01184669e+06]
#  [ -9.68299038e+06   4.14120834e+08]]
# [[  2.77735500e+06  -1.18781546e+08]
#  [ -1.13669450e+09   4.86139979e+10]]
# [[  3.26036073e+08  -1.39438670e+10]
#  [ -1.33437537e+11   5.70683867e+12]]
# [[  3.82736526e+10  -1.63688244e+12]
#  [ -1.56643462e+13   6.69930659e+14]]
# [[  4.49297673e+12  -1.92155026e+14]
#  [ -1.83885096e+15   7.86437314e+16]]
# [[  5.27434370e+14  -2.25572424e+16]
#  [ -2.15864283e+17   9.23205471e+18]]

# %% [markdown]
# # Tests with gaussian data

# %%
data, labels = linear_transform.gauss_data(n_samples=1000, classes=4, std=7)
linear_transform.plot_data(data, labels)

# %%
# Now let's apply some transformation technique
transforms = linear_transform.generate_linear_transform(data, labels, n_neighbors=30, iterations=1000, eps=0.1,
    max_class_data_on_iteration=50, balance_forces=True, potential=inv_potential)

for stage, transform in enumerate(transforms):
    confusion_matrix = utils.distance_quality_matrix(data, labels, n_neighbors=20)
    if stage % 100 == 0:
#         print transform
        X_new = numpy.dot(data, transform)
        linear_transform.plot_data(X_new, labels)
        qm = utils.distance_quality_matrix(X_new, labels, n_neighbors=20)
        utils.plot_confusion_matrix(qm)
        show()
